# %% [markdown]
# # ACE-Step Song Generator
#
# Free Suno-style song generator on Colab's T4 GPU. Set **Runtime > Change runtime type > T4 GPU**, then run the cells top to bottom. The last cell prints a public `gradio.live` link — open it on any phone or browser.
#
# First generation downloads ~7GB of model weights (several minutes). Download songs before the session ends. See the repo README for gotchas.

# %%
# !nvidia-smi

# %%
# !git clone https://github.com/ace-step/ACE-Step.git && cd ACE-Step && pip install -e . -q

# %%
# Required fix: Colab's preinstalled gradio 6.x breaks ACE-Step's UI
# !pip install -q gradio~=5.0

# %%
# !acestep --share true --bf16 false --torch_compile false --cpu_offload true --overlapped_decode true
